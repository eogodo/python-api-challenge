# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = ('http://api.openweathermap.org/data/2.5/weather?appid={0}&units=imperial&q=').format(weather_api_key)

print('Beginning Data Retrieval')
print('--------------------------------')

# set up lists to hold reponse info
cloud = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record = 0
record_set = 1

# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    try:
        response = requests.get(url + city).json()
        
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed']) 
        
        record += 1 
        if record==51: 
            record = 1
            record_set += 1 
        
        print(f'Processing Record {record} of Set {record_set} | {city}')
              
    except KeyError: 
        print('City not found. Skipping...')
        
print('--------------------------------')
print('Data Retrieval Complete')      
print('--------------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | guatire
# Processing Record 2 of Set 1 | tukrah
# Processing Record 3 of Set 1 | haines junction
# Processing Record 4 of Set 1 | chapais
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | urumqi
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | kaabong
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | marzuq
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | santa vitoria do palmar
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | medicine hat
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | ndele
# Processing Record 19 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 25 of Set 1 | marovoay
# Processing Record 26 of Set 1 | shingu
# Processing Record 27 of Set 1 | tsumeb
# Processing Record 28 of Set 1 | aklavik
# City not found. Skipping...
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | taltal
# Processing Record 31 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | vilyuysk
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | wanning
# City not found. Skipping...
# Processing Record 37 of Set 1 | ostrovnoy
# Processing Record 38 of Set 1 | antsohihy
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | sobolevo
# Processing Record 43 of Set 1 | fairbanks
# Processing Record 44 of Set 1 | flin flon
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | luderitz
# Processing Record 1 of Set 2 | quatre cocos
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | matara
# Processing Record 4 of Set 2 | jalu
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | grindavik
# Processing Record 7 of Set 2 | nakhon thai
# Processing Record 8 of Set 2 | kirksville
# Processing Record 9 of Set 2 | palampur
# Processing Record 10 of Set 2 | ustyuzhna
# Processing Record 11 of Set 2 | nicoya
# Processing Record 12 of Set 2 | unai
# Processing Record 13 of Set 2 | oistins
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | khash
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | provideniya
# Processing Record 20 of Set 2 | turayf
# Processing Record 21 of Set 2 | mayo
# Processing Record 22 of Set 2 | pangody
# Processing Record 23 of Set 2 | sol-iletsk
# Processing Record 24 of Set 2 | yatou
# Processing Record 25 of Set 2 | siocon
# Processing Record 26 of Set 2 | lunino
# Processing Record 27 of Set 2 | sidi ali
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | mandera
# Processing Record 30 of Set 2 | yaan
# Processing Record 31 of Set 2 | bathsheba
# Processing Record 32 of Set 2 | pemangkat
# Processing Record 33 of Set 2 | maine-soroa
# Processing Record 34 of Set 2 | aguas verdes
# Processing Record 35 of Set 2 | irbeyskoye
# Processing Record 36 of Set 2 | oksfjord
# Processing Record 37 of Set 2 | tres lagoas
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | baoro
# Processing Record 40 of Set 2 | shiyan
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | nouadhibou
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | leningradskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | half moon bay
# Processing Record 50 of Set 2 | atambua
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | zwedru
# Processing Record 3 of Set 3 | cascas
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | dubai
# Processing Record 7 of Set 3 | pisco
# Processing Record 8 of Set 3 | amaigbo
# Processing Record 9 of Set 3 | zdvinsk
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | emerald
# Processing Record 12 of Set 3 | san juan
# City not found. Skipping...
# Processing Record 13 of Set 3 | ballina
# Processing Record 14 of Set 3 | richards bay
# Processing Record 15 of Set 3 | les cayes
# Processing Record 16 of Set 3 | katsuura
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | wichian buri
# Processing Record 19 of Set 3 | goderich
# Processing Record 20 of Set 3 | kijang
# Processing Record 21 of Set 3 | kloulklubed
# Processing Record 22 of Set 3 | dangriga
# Processing Record 23 of Set 3 | gazojak
# City not found. Skipping...
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | cairns
# City not found. Skipping...
# Processing Record 26 of Set 3 | araouane
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | garwa
# Processing Record 29 of Set 3 | anadyr
# Processing Record 30 of Set 3 | rocha
# Processing Record 31 of Set 3 | nabire
# Processing Record 32 of Set 3 | puerto del rosario
# City not found. Skipping...
# Processing Record 33 of Set 3 | chuy
# City not found. Skipping...
# Processing Record 34 of Set 3 | alenquer
# City not found. Skipping...
# Processing Record 35 of Set 3 | alegrete
# Processing Record 36 of Set 3 | vaini
# Processing Record 37 of Set 3 | guiratinga
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | ambon
# Processing Record 40 of Set 3 | pointe-noire
# Processing Record 41 of Set 3 | ponta do sol
# City not found. Skipping...
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | jermuk
# Processing Record 44 of Set 3 | mount isa
# City not found. Skipping...
# Processing Record 45 of Set 3 | rusape
# Processing Record 46 of Set 3 | oktyabrskiy
# Processing Record 47 of Set 3 | airai
# Processing Record 48 of Set 3 | necochea
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | holland
# Processing Record 1 of Set 4 | hambantota
# Processing Record 2 of Set 4 | yelizovo
# Processing Record 3 of Set 4 | siniscola
# Processing Record 4 of Set 4 | xai-xai
# City not found. Skipping...
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | sur
# Processing Record 7 of Set 4 | calamar
# Processing Record 8 of Set 4 | moroni
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | kahului
# City not found. Skipping...
# Processing Record 11 of Set 4 | hasaki
# Processing Record 12 of Set 4 | salalah
# Processing Record 13 of Set 4 | yellowknife
# Processing Record 14 of Set 4 | poum
# Processing Record 15 of Set 4 | geraldton
# Processing Record 16 of Set 4 | lazarev
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | buala
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | einsiedeln
# Processing Record 22 of Set 4 | pevek
# Processing Record 23 of Set 4 | lawrenceburg
# Processing Record 24 of Set 4 | carmo do rio claro
# Processing Record 25 of Set 4 | bubaque
# Processing Record 26 of Set 4 | nome
# City not found. Skipping...
# Processing Record 27 of Set 4 | bitung
# Processing Record 28 of Set 4 | ocos
# Processing Record 29 of Set 4 | garden city
# Processing Record 30 of Set 4 | donna
# Processing Record 31 of Set 4 | sulangan
# Processing Record 32 of Set 4 | dezful
# Processing Record 33 of Set 4 | palmer
# City not found. Skipping...
# Processing Record 34 of Set 4 | tura
# Processing Record 35 of Set 4 | hachinohe
# Processing Record 36 of Set 4 | guerrero negro
# Processing Record 37 of Set 4 | prince rupert
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | cherskiy
# Processing Record 40 of Set 4 | fort nelson
# Processing Record 41 of Set 4 | birjand
# Processing Record 42 of Set 4 | san ramon
# Processing Record 43 of Set 4 | namibe
# Processing Record 44 of Set 4 | townsville
# Processing Record 45 of Set 4 | muisne
# Processing Record 46 of Set 4 | digras
# Processing Record 47 of Set 4 | nizwa
# Processing Record 48 of Set 4 | bady bassitt
# Processing Record 49 of Set 4 | acari
# Processing Record 50 of Set 4 | manacor
# Processing Record 1 of Set 5 | celestun
# Processing Record 2 of Set 5 | ust-kut
# Processing Record 3 of Set 5 | arraial do cabo
# City not found. Skipping...
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | sherlovaya gora
# Processing Record 6 of Set 5 | adrar
# Processing Record 7 of Set 5 | kizema
# Processing Record 8 of Set 5 | salekhard
# Processing Record 9 of Set 5 | flinders
# Processing Record 10 of Set 5 | virginia beach
# Processing Record 11 of Set 5 | bismarck
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | tupik
# Processing Record 14 of Set 5 | miri
# Processing Record 15 of Set 5 | shubarshi
# Processing Record 16 of Set 5 | barrow
# Processing Record 17 of Set 5 | yamada
# Processing Record 18 of Set 5 | lakes entrance
# Processing Record 19 of Set 5 | san lorenzo
# Processing Record 20 of Set 5 | mogadishu
# Processing Record 21 of Set 5 | norman wells
# Processing Record 22 of Set 5 | bethel
# City not found. Skipping...
# Processing Record 23 of Set 5 | ancud
# Processing Record 24 of Set 5 | jumla
# Processing Record 25 of Set 5 | bonthe
# Processing Record 26 of Set 5 | kununurra
# Processing Record 27 of Set 5 | yeniseysk
# Processing Record 28 of Set 5 | katherine
# Processing Record 29 of Set 5 | deputatskiy
# Processing Record 30 of Set 5 | manggar
# Processing Record 31 of Set 5 | ilo
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | walvis bay
# Processing Record 34 of Set 5 | hithadhoo
# Processing Record 35 of Set 5 | vestmannaeyjar
# Processing Record 36 of Set 5 | dalbandin
# Processing Record 37 of Set 5 | yarmouth
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | naze
# Processing Record 40 of Set 5 | vila velha
# Processing Record 41 of Set 5 | suntar
# Processing Record 42 of Set 5 | cabedelo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 5 | wewak
# Processing Record 44 of Set 5 | jambi
# Processing Record 45 of Set 5 | anacortes
# Processing Record 46 of Set 5 | la orilla
# Processing Record 47 of Set 5 | iqaluit
# Processing Record 48 of Set 5 | chishan
# Processing Record 49 of Set 5 | launceston
# Processing Record 50 of Set 5 | whitehorse
# Processing Record 1 of Set 6 | esperance
# Processing Record 2 of Set 6 | nuevo progreso
# Processing Record 3 of Set 6 | yakima
# Processing Record 4 of Set 6 | san vicente
# Processing Record 5 of Set 6 | fairmont
# Processing Record 6 of Set 6 | greencastle
# Processing Record 7 of Set 6 | nuuk
# Processing Record 8 of Set 6 | kastamonu
# Processing Record 9 of Set 6 | darnah
# City not found. Skipping...
# Processing Record 10 of Set 6 | rabo de peixe
# City not found. Skipping...
# Processing Record 11 of Set 6 | boda
# Processing Record 12 of Set 6 | fortuna
# Processing Record 13 of Set 6 | kumasi
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | uyuni
# Processing Record 16 of Set 6 | labuhan
# Processing Record 17 of Set 6 | itarema
# Processing Record 18 of Set 6 | durant
# Processing Record 19 of Set 6 | broome
# Processing Record 20 of Set 6 | mehamn
# City not found. Skipping...
# Processing Record 21 of Set 6 | sadiqabad
# Processing Record 22 of Set 6 | kavaratti
# Processing Record 23 of Set 6 | puerto escondido
# Processing Record 24 of Set 6 | kudahuvadhoo
# Processing Record 25 of Set 6 | port lincoln
# Processing Record 26 of Set 6 | wairoa
# Processing Record 27 of Set 6 | diffa
# City not found. Skipping...
# Processing Record 28 of Set 6 | karratha
# Processing Record 29 of Set 6 | khani
# Processing Record 30 of Set 6 | beyneu
# Processing Record 31 of Set 6 | gibara
# Processing Record 32 of Set 6 | laguna
# Processing Record 33 of Set 6 | kazachinskoye
# City not found. Skipping...
# Processing Record 34 of Set 6 | tapejara
# City not found. Skipping...
# Processing Record 35 of Set 6 | sola
# Processing Record 36 of Set 6 | port hedland
# Processing Record 37 of Set 6 | san pedro
# Processing Record 38 of Set 6 | kovdor
# Processing Record 39 of Set 6 | marand
# Processing Record 40 of Set 6 | marawi
# City not found. Skipping...
# Processing Record 41 of Set 6 | cabudare
# Processing Record 42 of Set 6 | port elizabeth
# Processing Record 43 of Set 6 | tezu
# Processing Record 44 of Set 6 | revelstoke
# Processing Record 45 of Set 6 | lozuvatka
# Processing Record 46 of Set 6 | santa cruz
# Processing Record 47 of Set 6 | mahon
# Processing Record 48 of Set 6 | turukhansk
# City not found. Skipping...
# Processing Record 49 of Set 6 | tagbac
# Processing Record 50 of Set 6 | nanortalik
# Processing Record 1 of Set 7 | rockport
# City not found. Skipping...
# Processing Record 2 of Set 7 | marystown
# Processing Record 3 of Set 7 | aksarka
# Processing Record 4 of Set 7 | odienne
# Processing Record 5 of Set 7 | acapulco
# Processing Record 6 of Set 7 | tateyama
# City not found. Skipping...
# Processing Record 7 of Set 7 | umm kaddadah
# Processing Record 8 of Set 7 | kokopo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 7 | saint-joseph
# Processing Record 10 of Set 7 | bichena
# Processing Record 11 of Set 7 | waverley
# Processing Record 12 of Set 7 | kulhudhuffushi
# Processing Record 13 of Set 7 | moose factory
# Processing Record 14 of Set 7 | la ronge
# Processing Record 15 of Set 7 | bat khela
# Processing Record 16 of Set 7 | constantine
# Processing Record 17 of Set 7 | ternate
# Processing Record 18 of Set 7 | alta floresta
# Processing Record 19 of Set 7 | paragominas
# Processing Record 20 of Set 7 | ketchikan
# Processing Record 21 of Set 7 | torbay
# Processing Record 22 of Set 7 | marinette
# Processing Record 23 of Set 7 | ahipara
# City not found. Skipping...
# Processing Record 24 of Set 7 | bhadrachalam
# Processing Record 25 of Set 7 | qena
# Processing Record 26 of Set 7 | kyabram
# Processing Record 27 of Set 7 | hurghada
# Processing Record 28 of Set 7 | balkanabat
# City not found. Skipping...
# Processing Record 29 of Set 7 | wangaratta
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | luleburgaz
# Processing Record 32 of Set 7 | eyl
# Processing Record 33 of Set 7 | bambous virieux
# Processing Record 34 of Set 7 | touros
# Processing Record 35 of Set 7 | cabrobo
# Processing Record 36 of Set 7 | mandalgovi
# Processing Record 37 of Set 7 | metu
# Processing Record 38 of Set 7 | carberry
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | baruun-urt
# Processing Record 41 of Set 7 | bougouni
# Processing Record 42 of Set 7 | bowen
# Processing Record 43 of Set 7 | rio gallegos
# Processing Record 44 of Set 7 | shibetsu
# City not found. Skipping...
# Processing Record 45 of Set 7 | neuruppin
# Processing Record 46 of Set 7 | presidencia roque saenz pena
# Processing Record 47 of Set 7 | bazaliya
# Processing Record 48 of Set 7 | forbes
# Processing Record 49 of Set 7 | ayni
# Processing Record 50 of Set 7 | luanda
# Processing Record 1 of Set 8 | zharkovskiy
# City not found. Skipping...
# Processing Record 2 of Set 8 | sao filipe
# Processing Record 3 of Set 8 | kupang
# Processing Record 4 of Set 8 | urusha
# Processing Record 5 of Set 8 | kuala pilah
# City not found. Skipping...
# Processing Record 6 of Set 8 | bata
# Processing Record 7 of Set 8 | maldonado
# Processing Record 8 of Set 8 | sergeyevka
# City not found. Skipping...
# Processing Record 9 of Set 8 | pangkalanbuun
# Processing Record 10 of Set 8 | san cristobal
# Processing Record 11 of Set 8 | shelburne
# Processing Record 12 of Set 8 | price
# Processing Record 13 of Set 8 | millau
# Processing Record 14 of Set 8 | basco
# Processing Record 15 of Set 8 | tabuk
# Processing Record 16 of Set 8 | souillac
# Processing Record 17 of Set 8 | salta
# Processing Record 18 of Set 8 | tucuman
# Processing Record 19 of Set 8 | vila do maio
# Processing Record 20 of Set 8 | kenai
# Processing Record 21 of Set 8 | blackwater
# Processing Record 22 of Set 8 | padang
# Processing Record 23 of Set 8 | ulladulla
# Processing Record 24 of Set 8 | bose
# Processing Record 25 of Set 8 | ixtapa
# Processing Record 26 of Set 8 | gigmoto
# Processing Record 27 of Set 8 | toora-khem
# Processing Record 28 of Set 8 | lumeje
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | pacific grove
# Processing Record 31 of Set 8 | daloa
# Processing Record 32 of Set 8 | jonkoping
# Processing Record 33 of Set 8 | aykhal
# Processing Record 34 of Set 8 | saint george
# City not found. Skipping...
# Processing Record 35 of Set 8 | tecoanapa
# Processing Record 36 of Set 8 | funtua
# City not found. Skipping...
# Processing Record 37 of Set 8 | baracoa
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | elsfleth
# Processing Record 40 of Set 8 | north bend
# Processing Record 41 of Set 8 | lagos
# Processing Record 42 of Set 8 | grants pass
# Processing Record 43 of Set 8 | cartagena del chaira
# Processing Record 44 of Set 8 | pochutla
# Processing Record 45 of Set 8 | yantal
# Processing Record 46 of Set 8 | vostok
# Processing Record 47 of Set 8 | talcahuano
# Processing Record 48 of Set 8 | ueki
# Processing Record 49 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 8 | mozarlandia
# Processing Record 1 of Set 9 | batagay
# Processing Record 2 of Set 9 | mangrol
# Processing Record 3 of Set 9 | rongcheng
# Processing Record 4 of Set 9 | broken hill
# Processing Record 5 of Set 9 | shubarkuduk
# Processing Record 6 of Set 9 | marsh harbour
# Processing Record 7 of Set 9 | pizhanka
# Processing Record 8 of Set 9 | urengoy
# Processing Record 9 of Set 9 | katobu
# City not found. Skipping...
# Processing Record 10 of Set 9 | caravelas
# Processing Record 11 of Set 9 | gat
# Processing Record 12 of Set 9 | vanimo
# Processing Record 13 of Set 9 | lincoln
# Processing Record 14 of Set 9 | dingle
# Processing Record 15 of Set 9 | sioux lookout
# Processing Record 16 of Set 9 | candolim
# Processing Record 17 of Set 9 | kirakira
# Processing Record 18 of Set 9 | cockburn town
# Processing Record 19 of Set 9 | calnali
# Processing Record 20 of Set 9 | sungaipenuh
# Processing Record 21 of Set 9 | ojuelos de jalisco
# Processing Record 22 of Set 9 | mezen
# Processing Record 23 of Set 9 | khvoynaya
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | alofi
# City not found. Skipping...
# Processing Record 26 of Set 9 | burnie
# Processing Record 27 of Set 9 | ngama
# City not found. Skipping...
# Processing Record 28 of Set 9 | toul
# City not found. Skipping...
# Processing Record 29 of Set 9 | bodmin
# Processing Record 30 of Set 9 | la palma
# Processing Record 31 of Set 9 | tiksi
# Processing Record 32 of Set 9 | ust-ilimsk
# Processing Record 33 of Set 9 | acarau
# Processing Record 34 of Set 9 | srednekolymsk
# Processing Record 35 of Set 9 | kaitangata
# Processing Record 36 of Set 9 | vadso
# City not found. Skipping...
# Processing Record 37 of Set 9 | saint-augustin
# Processing Record 38 of Set 9 | klaksvik
# Processing Record 39 of Set 9 | umm lajj
# Processing Record 40 of Set 9 | tevaitoa
# Processing Record 41 of Set 9 | isangel
# Processing Record 42 of Set 9 | santa maria
# Processing Record 43 of Set 9 | esna
# Processing Record 44 of Set 9 | alcudia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 9 | hue
# Processing Record 46 of Set 9 | miranda
# Processing Record 47 of Set 9 | aukra
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | tosham
# Processing Record 50 of Set 9 | roma
# Processing Record 1 of Set 10 | namatanai
# Processing Record 2 of Set 10 | paamiut
# Processing Record 3 of Set 10 | puerto quijarro
# Processing Record 4 of Set 10 | nivala
# Processing Record 5 of Set 10 | telimele
# City not found. Skipping...
# Processing Record 6 of Set 10 | charters towers
# Processing Record 7 of Set 10 | sao sebastiao
# Processing Record 8 of Set 10 | egvekinot
# Processing Record 9 of Set 10 | bandarbeyla
# Processing Record 10 of Set 10 | nurota
# Processing Record 11 of Set 10 | lebanon
# Processing Record 12 of Set 10 | nioro
# Processing Record 13 of Set 10 | bergerac
# Processing Record 14 of Set 10 | kamina
# Processing Record 15 of Set 10 | tessalit
# Processing Record 16 of Set 10 | laurel
# Processing Record 17 of Set 10 | margate
# Processing Record 18 of Set 10 | sovetskiy
# Processing Record 19 of Set 10 | bilma
# Processing Record 20 of Set 10 | vao
# Processing Record 21 of Set 10 | albertville
# Processing Record 22 of Set 10 | goundam
# Processing Record 23 of Set 10 | basoko
# Processing Record 24 of Set 10 | nautanwa
# Processing Record 25 of Set 10 | piacenza
# Processing Record 26 of Set 10 | colomi
# Processing Record 27 of Set 10 | hamilton
# Processing Record 28 of Set 10 | shirakawa
# Processing Record 29 of Set 10 | otaki
# Processing Record 30 of Set 10 | ust-maya
# Processing Record 31 of Set 10 | lata
# Processing Record 32 of Set 10 | chimbote
# Processing Record 33 of Set 10 | kundiawa
# Processing Record 34 of Set 10 | pangnirtung
# Processing Record 35 of Set 10 | saint-honore
# Processing Record 36 of Set 10 | daru
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 10 | avera
# Processing Record 38 of Set 10 | constitucion
# Processing Record 39 of Set 10 | nizhneangarsk
# Processing Record 40 of Set 10 | kpalime
# Processing Record 41 of Set 10 | gamboma
# Processing Record 42 of Set 10 | hirara
# Processing Record 43 of Set 10 | yima
# Processing Record 44 of Set 10 | windhoek
# Processing Record 45 of Set 10 | visby
# Processing Record 46 of Set 10 | moree
# Processing Record 47 of Set 10 | muros
# Processing Record 48 of Set 10 | los llanos de aridane
# Processing Record 49 of Set 10 | woodstock
# Processing Record 50 of Set 10 | lavrentiya
# Processing Record 1 of Set 11 | katangli
# Processing Record 2 of Set 11 | kotka
# Processing Record 3 of Set 11 | athabasca
# Processing Record 4 of Set 11 | havoysund
# Processing Record 5 of Set 11 | sobradinho
# City not found. Skipping...
# Processing Record 6 of Set 11 | sibolga
# Processing Record 7 of Set 11 | krasnoselkup
# Processing Record 8 of Set 11 | eregli
# Processing Record 9 of Set 11 | gimli
# Processing Record 10 of Set 11 | zlobin
# Processing Record 11 of Set 11 | yeppoon
# Processing Record 12 of Set 11 | asekeyevo
# Processing Record 13 of Set 11 | nkowakowa
# Processing Record 14 of Set 11 | kem
# Processing Record 15 of Set 11 | shishou
# Processing Record 16 of Set 11 | kapoeta
# Processing Record 17 of Set 11 | salvador
# City not found. Skipping...
# Processing Record 18 of Set 11 | dubovskoye
# Processing Record 19 of Set 11 | lamu
# Processing Record 20 of Set 11 | mizdah
# Processing Record 21 of Set 11 | la motte-servolex
# Processing Record 22 of Set 11 | spornoye
# Processing Record 23 of Set 11 | udachnyy
# Processing Record 24 of Set 11 | antigonish
# Processing Record 25 of Set 11 | mandurah
# Processing Record 26 of Set 11 | los andes
# Processing Record 27 of Set 11 | santiago del estero
# Processing Record 28 of Set 11 | manavalakurichi
# Processing Record 29 of Set 11 | iringa
# Processing Record 30 of Set 11 | jinchang
# Processing Record 31 of Set 11 | fuzhou
# Processing Record 32 of Set 11 | kostino
# Processing Record 33 of Set 11 | kruje
# Processing Record 34 of Set 11 | akureyri
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
output_data = pd.DataFrame((zip(cities,cloud,country,date,humidity,lat,lng,max_temp,wind_speed)),columns=['City', 'Cloudiness', 'Country', 'Date', 'Humidity','Lat','Lng','Max Temp','Wind Speed'])
output_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 9 columns):
# City          534 non-null object
# Cloudiness    534 non-null int64
# Country       534 non-null object
# Date          534 non-null int64
# Humidity      534 non-null int64
# Lat           534 non-null float64
# Lng           534 non-null float64
# Max Temp      534 non-null float64
# Wind Speed    534 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 37.7+ KB

# %%
# Output File (CSV)
output_file = output_data.to_csv('output_data/cities.csv',index=False,header=True)
output_data = pd.read_csv('output_data/cities.csv')
output_data.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          guatire          40      VE  1580249736        74  10.48  -66.54
# 1           tukrah           0      LY  1580249736        74  32.53   20.58
# 2  haines junction          26      CA  1580249737        95  60.75 -137.51
# 3          chapais           1      CA  1580249737        61  49.78  -74.85
# 4   severo-kurilsk          92      RU  1580249737        91  50.68  156.12
#
#    Max Temp  Wind Speed
# 0     84.20        4.70
# 1     56.50        8.48
# 2      8.19        8.72
# 3     14.00        6.93
# 4     21.76        5.03

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
today=date.today()
ax = output_data.plot.scatter(x='Lat',y='Max Temp',grid=True,title=f'City Latitude vs Max Temperature ({today.strftime("%m/%d/%y")})')
ax.set(xlabel='Latitude',ylabel='Max Temperature (F)')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
ax = output_data.plot.scatter(x='Lat',y='Humidity',grid=True,title=f'City Latitude vs Humidity ({today.strftime("%m/%d/%y")})')
ax.set(xlabel='Latitude',ylabel='Humidity (%)')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
ax = output_data.plot.scatter(x='Lat',y='Cloudiness',grid=True,title=f'City Latitude vs Cloudiness ({today.strftime("%m/%d/%y")})')
ax.set(xlabel='Latitude',ylabel='Cloudiness (%)')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
ax = output_data.plot.scatter(x='Lat',y='Wind Speed',grid=True,title=f'City Latitude vs Wind Speed ({today.strftime("%m/%d/%y")})')
ax.set(xlabel='Latitude',ylabel='Wind Speed (mph)')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regress(x,y):

    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    
    print(f'The rsquared is : {rvalue**2}')
    return(line_eq)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern = output_data.loc[output_data['Lat']>=0]
southern = output_data.loc[output_data['Lat']<0]
northern.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          guatire          40      VE  1580249736        74  10.48  -66.54
# 1           tukrah           0      LY  1580249736        74  32.53   20.58
# 2  haines junction          26      CA  1580249737        95  60.75 -137.51
# 3          chapais           1      CA  1580249737        61  49.78  -74.85
# 4   severo-kurilsk          92      RU  1580249737        91  50.68  156.12
#
#    Max Temp  Wind Speed
# 0     84.20        4.70
# 1     56.50        8.48
# 2      8.19        8.72
# 3     14.00        6.93
# 4     21.76        5.03

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_eq=linear_regress(northern['Lat'],northern['Max Temp'])
plt.annotate(line_eq,(5,-20),fontsize=15,color="red")
plt.title('City Latitude vs Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()
# Out:
# The rsquared is : 0.7960585101729765

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_eq=linear_regress(southern['Lat'],southern['Max Temp'])
plt.annotate(line_eq,(-30,45),fontsize=15,color="red")
plt.title('City Latitude vs Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()
# Out:
# The rsquared is : 0.1662998981969552

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_eq=linear_regress(northern['Lat'],northern['Humidity'])
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title('City Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
# Out:
# The rsquared is : 0.18045208544111507

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_eq=linear_regress(southern['Lat'],southern['Humidity'])
plt.annotate(line_eq,(-55,22),fontsize=15,color="red")
plt.title('City Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
# Out:
# The rsquared is : 0.07274724987879366

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_eq=linear_regress(northern['Lat'],northern['Cloudiness'])
plt.annotate(line_eq,(45,30),fontsize=15,color="red")
plt.title('City Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
# Out:
# The rsquared is : 0.09698947870058786

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_eq=linear_regress(southern['Lat'],southern['Cloudiness'])
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.title('City Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
# Out:
# The rsquared is : 0.060061298726429645

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_eq=linear_regress(northern['Lat'],northern['Wind Speed'])
plt.annotate(line_eq,(10,30),fontsize=15,color="red")
plt.title('City Latitude vs Windspeed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
# Out:
# The rsquared is : 0.0035251670422000603

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_eq=linear_regress(southern['Lat'],southern['Wind Speed'])
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.title('City Latitude vs Windspeed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
# Out:
# The rsquared is : 0.1608824511803621
